# %%
import math
import random
import pygame 
import tkinter as tk 
from tkinter import messegebox

class cabe(object):
    rows =0
    w=0
    def _int_(self,start,dirnx=1,dirny=0,color=(255,0,)):
        pass 
    def move(self, dirnx,dirny):
        pass
    def draw(self ,surface,eyes=false):
        pass

class snake(object):
    def _init_(self,color,pos):
        pass
    def move(self):
        pass
    def reset(self,pos):
        pass
    def addCube(self):
        pass
    def draw(self,surface):
        pass
def drawGrid(w,rows,surface):
    sizeBtwn=w//rows
    x=0
    y=0
    for i in range(rows):
        x=x+sizeBtwn
        y=y+sizeBtwn
        
        pygame.draw.line(surface,(255,255,255),(x,0),(x,w))
        pygame.draw.line(surface,(255,255,255),(0,y),(w,y))

def redrawWindow(surface):
    surface.fill((0,0,0))
    drawGrid(surface,width,rows)
    pygmae.display.update()


def randomSnack(rows,items):
    pass
def message_box(subject,content):
    pass
def main():
    global winth,rows
    width=500
    row=20
    win=pygame.display.ser_mode(width,width)
    s=snake((255,0,0),(10,10))
    flag=True
    
    clock=pygame.time.clock()
    
    while flag:
        pygame.time.delay(50)
        clock.tick(10)
        redrawWindow(win)
    pass
